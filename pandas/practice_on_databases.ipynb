# %% [markdown]
# # Real World Databases in series

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Basics

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Name": ["A", "B"],
    "Age": [20, 21],
    "City": ["Delhi", "Jaipur"]
})
df
# Out:
#   Name  Age    City
# 0    A   20   Delhi
# 1    B   21  Jaipur

# %%
df['City']
# Out:
# 0     Delhi
# 1    Jaipur
# Name: City, dtype: str

# %%
df[['City']]
# Out:
#      City
# 0   Delhi
# 1  Jaipur

# %%
df[["City", "Name"]]
# Out:
#      City Name
# 0   Delhi    A
# 1  Jaipur    B

# %%
import pandas as pd
import numpy as np

marks = pd.Series([85, np.nan, 90, np.nan, 78])

# %%
marks.isna() #isna = is + NA
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
marks.isna().sum()
# Out:
# np.int64(2)

# %%
marks.notna() # notna = not + NA
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
marks.sum()
# Out:
# np.float64(253.0)

# %%
marks.count() # It will count valid values and will ignore empty values
# Out:
# np.int64(3)

# %%
marks.mean() # Mean will calculated on valid values only eg. 3 here
# Out:
# np.float64(84.33333333333333)

# %%
df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Aman"],
    "Age": [20, 21, 19],
    "Marks": [85, 90, 88]
})

# %%
df['Marks'].sum()
# Out:
# np.int64(263)

# %% [markdown]
# ## DataFrames Attributes

# %%
df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Aman"],
    "Age": [20, 21, 19],
    "Marks": [85, 90, 88]
})

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.dtypes
# Out:
# Name       str
# Age      int64
# Marks    int64
# dtype: object

# %%
df.head(2) # head() returns rows from the top instead of full dataframe
# Out:
#     Name  Age  Marks
# 0  Rahul   20     85
# 1  Priya   21     90

# %%
df.tail(1) # tail() returns rows from the bottom
# Out:
#    Name  Age  Marks
# 2  Aman   19     88

# %%
df.head(100) # if the input value is more than rows than it will return the available number of rows same for tail()
# Out:
#     Name  Age  Marks
# 0  Rahul   20     85
# 1  Priya   21     90
# 2   Aman   19     88

# %%
df.sample(2) # sample() returns random rows
# Out:
#     Name  Age  Marks
# 1  Priya   21     90
# 0  Rahul   20     85

# %%
df.describe() 

#df.describe()
# Answers different questions:

# What's the average?
# What's the minimum?
# What's the maximum?
# What's the standard deviation?
# What are the quartiles (25%, 50%, 75%)?

# It's the statistical summary of your numeric columns
# Out:
#         Age      Marks
# count   3.0   3.000000
# mean   20.0  87.666667
# std     1.0   2.516611
# min    19.0  85.000000
# 25%    19.5  86.500000
# 50%    20.0  88.000000
# 75%    20.5  89.000000
# max    21.0  90.000000

# %%
df.info()

# df.info()

# Answers questions like:

# How many rows are there?
# How many columns are there?
# What are the column names?
# What is the data type of each column?
# How many non-null (non-missing) values does each column have?
# How much memory is being used?

# It's basically the identity card of your DataFrame.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      str
#  1   Age     3 non-null      int64
#  2   Marks   3 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 204.0 bytes

# %%
df.rename(columns={"Marks": "Score"}) # Returns a new data frame with new column name
# Out:
#     Name  Age  Score
# 0  Rahul   20     85
# 1  Priya   21     90
# 2   Aman   19     88

# %%
df.rename(columns={"Age": "Student_Age"}, inplace=True) # Permanently changes the current data frame

# %%
df.set_index("Name") # Changes default index
# Out:
#        Student_Age  Marks
# Name
# Rahul           20     85
# Priya           21     90
# Aman            19     88

# %%
df.reset_index()
# Out:
#    index   Name  Student_Age  Marks
# 0      0  Rahul           20     85
# 1      1  Priya           21     90
# 2      2   Aman           19     88

# %% [markdown]
# ## Handling Missing Values

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    "Name": ["Rahul", "Priya"],
    "Age": [20, np.nan],
    "Marks": [np.nan, 90]
})

# %%
df.isnull() # isnull() checks which values are missing
# Out:
#     Name    Age  Marks
# 0  False  False   True
# 1  False   True  False

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      1
# Marks    1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(2)

# %%
df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Aman"],
    "Age": [20, np.nan, 19],
    "Marks": [85, 90, 75]
})

# %%
df.dropna() # Deletes rows which have missing values
# Out:
#     Name   Age  Marks
# 0  Rahul  20.0     85
# 2   Aman  19.0     75

# %%
df.fillna(18)
# Out:
#     Name   Age  Marks
# 0  Rahul  20.0     85
# 1  Priya  18.0     90
# 2   Aman  19.0     75

# %%
df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Aman"],
    "Age": [20, np.nan, 19],
    "Marks": [85, 90, np.nan]
})

# %%
df['Age'].fillna(18)
df['Marks'].fillna(80)
# Out:
# 0    85.0
# 1    90.0
# 2    80.0
# Name: Marks, dtype: float64

# %% [markdown]
# ## Fetching Columns and Rows

# %%
df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Aman"],
    "Student Age": [20, 18, 19],
    "Marks": [85, 90, 75]
})

# %%
print(df["Name"]) 
print(df.Name)   ## Both Returns Same results
# Out:
# 0    Rahul
# 1    Priya
# 2     Aman
# Name: Name, dtype: str
# 0    Rahul
# 1    Priya
# 2     Aman
# Name: Name, dtype: str

# %%
print(df["Student Age"])
# print(df.Student Age) ----- Dot notation doesnt works if the column have space in their name
# Out:
# 0    20
# 1    18
# 2    19
# Name: Student Age, dtype: int64

# %%
df[["Name", "Student Age", "Marks"]]
# Out:
#     Name  Student Age  Marks
# 0  Rahul           20     85
# 1  Priya           18     90
# 2   Aman           19     75

# %%
df.loc[1]
# Out:
# Name           Priya
# Student Age       18
# Marks             90
# Name: 1, dtype: object

# %%
df.loc[1,"Name"] # loc can select both rows and columns
# Out:
# 'Priya'

# %%
df.loc[1:3]
# Out:
#     Name  Student Age  Marks
# 1  Priya           18     90
# 2   Aman           19     75

# %%
df.loc[1:3, ["Name"]]
# Out:
#     Name
# 1  Priya
# 2   Aman

# %%
df.loc[[0, 2], ["Name", "Student Age"]]
# Out:
#     Name  Student Age
# 0  Rahul           20
# 2   Aman           19

# %%
df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Aman", "Mohit", "Diksha", "Nishant"],
    "Student Age": [20, 18, 19,18,19,20],
    "Marks": [85, 90, 75, 60, 84, 74]
})

# %%
df.sort_values('Marks')
# Out:
#       Name  Student Age  Marks
# 3    Mohit           18     60
# 5  Nishant           20     74
# 2     Aman           19     75
# 4   Diksha           19     84
# 0    Rahul           20     85
# 1    Priya           18     90

# %%
df.sort_values('Marks', ascending = False)
# Out:
#       Name  Student Age  Marks
# 1    Priya           18     90
# 0    Rahul           20     85
# 4   Diksha           19     84
# 2     Aman           19     75
# 5  Nishant           20     74
# 3    Mohit           18     60

# %%
df.sort_values(["Student Age", "Marks"], ascending = [True, False])
# Out:
#       Name  Student Age  Marks
# 1    Priya           18     90
# 3    Mohit           18     60
# 4   Diksha           19     84
# 2     Aman           19     75
# 0    Rahul           20     85
# 5  Nishant           20     74

# %% [markdown]
# ## Filtering, Adding New Columns and Other Functions

# %% [markdown]
# ### Filtering Rows and Columns

# %%
import pandas as pd
df = pd.DataFrame({
    "Name": ["Rahul", "Akshita", "Aman", "Mohit", "Diksha", "Nonny"],
    "Age": [20, 18, 19,18,19,20],
    "Marks": [85, 90, 75, 60, 84, 74],
    "Branch": ["ME","CS", "CS","EE","CS","CS"]
})

# %%
df.loc[[2,1], ["Name", "Age"]]
# Out:
#       Name  Age
# 2     Aman   19
# 1  Akshita   18

# %%
df.sort_values(["Branch", "Marks", "Age"], ascending=[True, True, False])
# Out:
#       Name  Age  Marks Branch
# 5    Nonny   20     74     CS
# 2     Aman   19     75     CS
# 4   Diksha   19     84     CS
# 1  Akshita   18     90     CS
# 3    Mohit   18     60     EE
# 0    Rahul   20     85     ME

# %%
df[df["Marks"]>80]
# Out:
#       Name  Age  Marks Branch
# 0    Rahul   20     85     ME
# 1  Akshita   18     90     CS
# 4   Diksha   19     84     CS

# %%
df[df["Branch"]=="CS"]
# Out:
#       Name  Age  Marks Branch
# 1  Akshita   18     90     CS
# 2     Aman   19     75     CS
# 4   Diksha   19     84     CS
# 5    Nonny   20     74     CS

# %%
df[(df["Branch"]== "CS")& (df["Marks"]> 80)]
# Out:
#       Name  Age  Marks Branch
# 1  Akshita   18     90     CS
# 4   Diksha   19     84     CS

# %%
df[(df["Branch"]== "CS") | (df["Marks"]> 80)]
# Out:
#       Name  Age  Marks Branch
# 0    Rahul   20     85     ME
# 1  Akshita   18     90     CS
# 2     Aman   19     75     CS
# 4   Diksha   19     84     CS
# 5    Nonny   20     74     CS

# %%
df[~(df["Branch"]== "CS") & ~(df["Marks"]> 80)]  ## '~' means not
# Out:
#     Name  Age  Marks Branch
# 3  Mohit   18     60     EE

# %% [markdown]
# ### Special Filtering Methods

# %%
# isin()
df[df["Age"].isin([18,20])]
# Out:
#       Name  Age  Marks Branch
# 0    Rahul   20     85     ME
# 1  Akshita   18     90     CS
# 3    Mohit   18     60     EE
# 5    Nonny   20     74     CS

# %%
## between()
df[df["Age"].between(18,20)]
# Out:
#       Name  Age  Marks Branch
# 0    Rahul   20     85     ME
# 1  Akshita   18     90     CS
# 2     Aman   19     75     CS
# 3    Mohit   18     60     EE
# 4   Diksha   19     84     CS
# 5    Nonny   20     74     CS

# %% [markdown]
# ### Adding and Modifying Columns

# %%
df["City"] = ["Alwar", "Jaipur", "Shahpura DC", "Alwar", "Jaipur", "St. Bagar"]

# %%
df["Percentage"] = (df["Marks"] + 500) / 600 * 100

# %%
df
# Out:
#       Name  Age  Marks Branch         City  Percentage
# 0    Rahul   20     85     ME        Alwar   97.500000
# 1  Akshita   18     90     CS       Jaipur   98.333333
# 2     Aman   19     75     CS  Shahpura DC   95.833333
# 3    Mohit   18     60     EE        Alwar   93.333333
# 4   Diksha   19     84     CS       Jaipur   97.333333
# 5    Nonny   20     74     CS    St. Bagar   95.666667

# %%
df["Marks"] = df["Marks"] - 10
df
# Out:
#       Name  Age  Marks Branch         City  Percentage
# 0    Rahul   20     75     ME        Alwar   97.500000
# 1  Akshita   18     80     CS       Jaipur   98.333333
# 2     Aman   19     65     CS  Shahpura DC   95.833333
# 3    Mohit   18     50     EE        Alwar   93.333333
# 4   Diksha   19     74     CS       Jaipur   97.333333
# 5    Nonny   20     64     CS    St. Bagar   95.666667

# %% [markdown]
# ### Conditional Columns

# %%
import numpy as np

df["Category"] = np.where(
    df["Marks"] >= 60,
    "Excellent",
    "Good"
)

# %%
df
# Out:
#       Name  Age  Marks Branch         City  Percentage   Category
# 0    Rahul   20     75     ME        Alwar   97.500000  Excellent
# 1  Akshita   18     80     CS       Jaipur   98.333333  Excellent
# 2     Aman   19     65     CS  Shahpura DC   95.833333  Excellent
# 3    Mohit   18     50     EE        Alwar   93.333333       Good
# 4   Diksha   19     74     CS       Jaipur   97.333333  Excellent
# 5    Nonny   20     64     CS    St. Bagar   95.666667  Excellent

# %%
conditions = [
    df["Marks"] >= 60,
    df["Marks"] >= 45,
    df["Marks"] >= 30
]

choices = [
    "A",
    "B",
    "C"
]

df["Grade"] = np.select(
    conditions,
    choices,
    default="F"
)

df
# Out:
#       Name  Age  Marks Branch         City  Percentage   Category Grade
# 0    Rahul   20     75     ME        Alwar   97.500000  Excellent     A
# 1  Akshita   18     80     CS       Jaipur   98.333333  Excellent     A
# 2     Aman   19     65     CS  Shahpura DC   95.833333  Excellent     A
# 3    Mohit   18     50     EE        Alwar   93.333333       Good     B
# 4   Diksha   19     74     CS       Jaipur   97.333333  Excellent     A
# 5    Nonny   20     64     CS    St. Bagar   95.666667  Excellent     A

# %% [markdown]
# ### Filtering Rows by Category

# %%
## groupby()
df.groupby("Branch")["Marks"].mean()
# Out:
# Branch
# CS    70.75
# EE    50.00
# ME    75.00
# Name: Marks, dtype: float64

# %%
df.groupby("Branch")["Name"].count()
# Out:
# Branch
# CS    4
# EE    1
# ME    1
# Name: Name, dtype: int64

# %%
### Multiple Aggregations
df.groupby("Branch").agg({"Marks": ["mean", "max", "min"],"Name":"count"})
# Out:
#         Marks          Name
#          mean max min count
# Branch
# CS      70.75  80  64     4
# EE      50.00  50  50     1
# ME      75.00  75  75     1

# %% [markdown]
# ### Merging Two Dataframes

# %%
df2 = pd.DataFrame({
    "Name": ["Rahul", "Akshita", "Aman", "Mohit", "Diksha", "Nonny"],
    "Section": ["M1", "CA1", "CA1", "E1", "CY", "CB1"]
})

# %%
df3 = pd.merge(df,df2, on = "Name" )
df3
# Out:
#       Name  Age  Marks Branch         City  Percentage   Category Grade  \
# 0    Rahul   20     75     ME        Alwar   97.500000  Excellent     A
# 1  Akshita   18     80     CS       Jaipur   98.333333  Excellent     A
# 2     Aman   19     65     CS  Shahpura DC   95.833333  Excellent     A
# 3    Mohit   18     50     EE        Alwar   93.333333       Good     B
# 4   Diksha   19     74     CS       Jaipur   97.333333  Excellent     A
# 5    Nonny   20     64     CS    St. Bagar   95.666667  Excellent     A
#
#   Section
# 0      M1
# 1     CA1
# 2     CA1
# 3      E1
# 4      CY
# 5     CB1

# %%
pd.concat([df,df2]) ## Vertical Concatenation
# Out:
#       Name   Age  Marks Branch         City  Percentage   Category Grade  \
# 0    Rahul  20.0   75.0     ME        Alwar   97.500000  Excellent     A
# 1  Akshita  18.0   80.0     CS       Jaipur   98.333333  Excellent     A
# 2     Aman  19.0   65.0     CS  Shahpura DC   95.833333  Excellent     A
# 3    Mohit  18.0   50.0     EE        Alwar   93.333333       Good     B
# 4   Diksha  19.0   74.0     CS       Jaipur   97.333333  Excellent     A
# 5    Nonny  20.0   64.0     CS    St. Bagar   95.666667  Excellent     A
# 0    Rahul   NaN    NaN    NaN          NaN         NaN        NaN   NaN
# 1  Akshita   NaN    NaN    NaN          NaN         NaN        NaN   NaN
# 2     Aman   NaN    NaN    NaN          NaN         NaN        NaN   NaN
# 3    Mohit   NaN    NaN    NaN          NaN         NaN        NaN   NaN
# 4   Diksha   NaN    NaN    NaN          NaN         NaN        NaN   NaN
# 5    Nonny   NaN    NaN    NaN          NaN         NaN        NaN   NaN
#
#   Section
# ...

# %%
new__column = pd.DataFrame({
    "College": ["GECA","GECA","GECA",np.nan,"GECA", "GECA"]
})
df = pd.concat([df,new__column], axis = 1) ## Vertical Concatenation
df
# Out:
#       Name  Age  Marks Branch         City  Percentage   Category Grade  \
# 0    Rahul   20     75     ME        Alwar   97.500000  Excellent     A
# 1  Akshita   18     80     CS       Jaipur   98.333333  Excellent     A
# 2     Aman   19     65     CS  Shahpura DC   95.833333  Excellent     A
# 3    Mohit   18     50     EE        Alwar   93.333333       Good     B
# 4   Diksha   19     74     CS       Jaipur   97.333333  Excellent     A
# 5    Nonny   20     64     CS    St. Bagar   95.666667  Excellent     A
#
#   College
# 0    GECA
# 1    GECA
# 2    GECA
# 3     NaN
# 4    GECA
# 5    GECA

# %%
new_row = pd.DataFrame({
    "Name": ["Rohit"],
    "Age" : [19],
    "Branch": ["CS"],
    "City": ["Madar DC"]
})
cf = pd.concat([df,new_row], ignore_index= True)
cf
# Out:
#       Name  Age  Marks Branch         City  Percentage   Category Grade  \
# 0    Rahul   20   75.0     ME        Alwar   97.500000  Excellent     A
# 1  Akshita   18   80.0     CS       Jaipur   98.333333  Excellent     A
# 2     Aman   19   65.0     CS  Shahpura DC   95.833333  Excellent     A
# 3    Mohit   18   50.0     EE        Alwar   93.333333       Good     B
# 4   Diksha   19   74.0     CS       Jaipur   97.333333  Excellent     A
# 5    Nonny   20   64.0     CS    St. Bagar   95.666667  Excellent     A
# 6    Rohit   19    NaN     CS     Madar DC         NaN        NaN   NaN
#
#   College
# 0    GECA
# 1    GECA
# 2    GECA
# 3     NaN
# 4    GECA
# 5    GECA
# 6     NaN

# %%
new_row = pd.DataFrame({
    "Name": ["Aman"],
    "Age" : [19],
    "Branch": ["CS"],
    "City": ["Shahpura DC"],
    "Percentage": [95.833333],
    "Category" : ["Excellent"],
    "Grade": ["A"],
    "College": ["GECA"],
    "Marks": [65]
})
cf = pd.concat([df,new_row], ignore_index= True)
cf
# Out:
#       Name  Age  Marks Branch         City  Percentage   Category Grade  \
# 0    Rahul   20     75     ME        Alwar   97.500000  Excellent     A
# 1  Akshita   18     80     CS       Jaipur   98.333333  Excellent     A
# 2     Aman   19     65     CS  Shahpura DC   95.833333  Excellent     A
# 3    Mohit   18     50     EE        Alwar   93.333333       Good     B
# 4   Diksha   19     74     CS       Jaipur   97.333333  Excellent     A
# 5    Nonny   20     64     CS    St. Bagar   95.666667  Excellent     A
# 6     Aman   19     65     CS  Shahpura DC   95.833333  Excellent     A
#
#   College
# 0    GECA
# 1    GECA
# 2    GECA
# 3     NaN
# 4    GECA
# 5    GECA
# 6    GECA

# %%
cf.duplicated() ##Finds Duplicates
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
cf.drop_duplicates() ## Deletes Duplicates
# Out:
#       Name  Age  Marks Branch         City  Percentage   Category Grade  \
# 0    Rahul   20     75     ME        Alwar   97.500000  Excellent     A
# 1  Akshita   18     80     CS       Jaipur   98.333333  Excellent     A
# 2     Aman   19     65     CS  Shahpura DC   95.833333  Excellent     A
# 3    Mohit   18     50     EE        Alwar   93.333333       Good     B
# 4   Diksha   19     74     CS       Jaipur   97.333333  Excellent     A
# 5    Nonny   20     64     CS    St. Bagar   95.666667  Excellent     A
# 6     Aman   19     65     CS  Shahpura DC   95.833333  Excellent     A
#
#   College
# 0    GECA
# 1    GECA
# 2    GECA
# 3     NaN
# 4    GECA
# 5    GECA
# 6    GECA

# %%
cf.replace("Nonny","Nishant")
# Out:
#       Name  Age  Marks Branch         City  Percentage   Category Grade  \
# 0    Rahul   20     75     ME        Alwar   97.500000  Excellent     A
# 1  Akshita   18     80     CS       Jaipur   98.333333  Excellent     A
# 2     Aman   19     65     CS  Shahpura DC   95.833333  Excellent     A
# 3    Mohit   18     50     EE        Alwar   93.333333       Good     B
# 4   Diksha   19     74     CS       Jaipur   97.333333  Excellent     A
# 5  Nishant   20     64     CS    St. Bagar   95.666667  Excellent     A
# 6     Aman   19     65     CS  Shahpura DC   95.833333  Excellent     A
#
#   College
# 0    GECA
# 1    GECA
# 2    GECA
# 3     NaN
# 4    GECA
# 5    GECA
# 6    GECA

# %%
cf.loc[2].equals(cf.loc[6])
# Out:
# False

# %%
cf.dtypes
# Out:
# Name              str
# Age             int64
# Marks           int64
# Branch            str
# City              str
# Percentage    float64
# Category          str
# Grade             str
# College           str
# dtype: object

# %%
cf.loc[2]
# Out:
# Name                 Aman
# Age                    19
# Marks                  65
# Branch                 CS
# City          Shahpura DC
# Percentage      95.833333
# Category        Excellent
# Grade                   A
# College              GECA
# Name: 2, dtype: object

# %%
cf.loc[6]
# Out:
# Name                 Aman
# Age                    19
# Marks                  65
# Branch                 CS
# City          Shahpura DC
# Percentage      95.833333
# Category        Excellent
# Grade                   A
# College              GECA
# Name: 6, dtype: object

# %%
df[["Marks","Percentage","Age"]].corr()
# Out:
#                Marks  Percentage       Age
# Marks       1.000000    1.000000  0.187175
# Percentage  1.000000    1.000000  0.187175
# Age         0.187175    0.187175  1.000000

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(
    x = "Name",
    y = "Marks",
    kind = "bar"
)
# Out:
# <Axes: xlabel='Name'>
