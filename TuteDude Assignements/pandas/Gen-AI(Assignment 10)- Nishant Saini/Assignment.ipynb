# %%
import pandas as pd
marks = [78,85,90,66,72]
s = pd.Series(marks)
print(s)
print(s.index)
print(s.dtype)
print(s.loc[0])
print(s.iloc[-2:])

s1 = s.add(5)
s2 = s.sub(2)
s3 = s*1.05
s4 = s/2
# Out:
# 0    78
# 1    85
# 2    90
# 3    66
# 4    72
# dtype: int64
# RangeIndex(start=0, stop=5, step=1)
# int64
# 78
# 3    66
# 4    72
# dtype: int64

# %%
print("After adding 5:")
print(s1)

print("\nAfter subtracting 2:")
print(s2)

print("\nAfter multiplying by 1.05:")
print(s3)

print("\nAfter dividing by 2:")
print(s4)
# Out:
# After adding 5:
# 0    83
# 1    90
# 2    95
# 3    71
# 4    77
# dtype: int64
#
# After subtracting 2:
# 0    76
# 1    83
# 2    88
# 3    64
# 4    70
# dtype: int64
#
# After multiplying by 1.05:
# 0    81.90
# 1    89.25
# 2    94.50
# 3    69.30
# 4    75.60
# dtype: float64
#
# After dividing by 2:
# 0    39.0
# 1    42.5
# 2    45.0
# 3    33.0
# 4    36.0
# dtype: float64

# %%
print(f"Maximum Marks: {s.max()}")
print(f"\nMinimum Marks: {s.min()}")
print(f"\nAverage Marks: {s.mean()}")
print(f"\nTotal Marks: {s.sum()}")
result = (s.apply(lambda x: "Pass" if x >= 70 else "Failed"))
print(result)
print(f"\nStudents Passed: {(result == 'Pass').sum()}")
# Out:
# Maximum Marks: 90
#
# Minimum Marks: 66
#
# Average Marks: 78.2
#
# Total Marks: 391
# 0      Pass
# 1      Pass
# 2      Pass
# 3    Failed
# 4      Pass
# dtype: str
#
# Students Passed: 4

# %%
students = pd.DataFrame({
    "Name": ["Amit", "Neha", "Rahul", "Sneha", "Pooja"],
    "Marks": [78, 85, 90, 66, 72],
    "Subject": ["Math", "Math", "Science", "Science", "Math"]
})
print(students)

print("\nFirst 3 rows:")
print(students.head(3))
print("\nLast 2 rows:")
print(students.tail(2))

print("\nColumns:")
print(students.columns)

print("\nShape:")
print(students.shape)
# Out:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
# 3  Sneha     66  Science
# 4  Pooja     72     Math
#
# First 3 rows:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
#
# Last 2 rows:
#     Name  Marks  Subject
# 3  Sneha     66  Science
# 4  Pooja     72     Math
#
# Columns:
# Index(['Name', 'Marks', 'Subject'], dtype='str')
#
# Shape:
# (5, 3)

# %%
students.info()
print(students.describe())
print(students.head())
print(students.tail())
sorting = students.sort_values("Marks", ascending=False)
print(sorting)
print(sorting.reset_index())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      str
#  1   Marks    5 non-null      int64
#  2   Subject  5 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 252.0 bytes
#            Marks
# count   5.000000
# mean   78.200000
# std     9.654015
# min    66.000000
# 25%    72.000000
# 50%    78.000000
# 75%    85.000000
# max    90.000000
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
# 3  Sneha     66  Science
# 4  Pooja     72     Math
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
# 3  Sneha     66  Science
# 4  Pooja     72     Math
#     Name  Marks  Subject
# 2  Rahul     90  Science
# 1   Neha     85     Math
# 0   Amit     78     Math
# 4  Pooja     72     Math
# 3  Sneha     66  Science
# ...

# %%
print(students[students["Marks"] > 75])
print(students[students["Subject"] == "Math"])
print(students[students["Marks"] > students["Marks"].mean()])
print(students[students["Marks"] < 70])
# Out:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
#     Name  Marks Subject
# 0   Amit     78    Math
# 1   Neha     85    Math
# 4  Pooja     72    Math
#     Name  Marks  Subject
# 1   Neha     85     Math
# 2  Rahul     90  Science
#     Name  Marks  Subject
# 3  Sneha     66  Science

# %%
print(students.groupby("Subject")["Marks"].mean())
print(students.groupby("Subject")["Name"].count())
print(students.groupby("Subject")["Marks"].max())
# Out:
# Subject
# Math       78.333333
# Science    78.000000
# Name: Marks, dtype: float64
# Subject
# Math       3
# Science    2
# Name: Name, dtype: int64
# Subject
# Math       85
# Science    90
# Name: Marks, dtype: int64

# %%
students.plot(
    x="Name",
    y="Marks",
    kind="bar"
)
# Out:
# <Axes: xlabel='Name'>

# %%
students["Marks"].plot(kind = "line")
# Out:
# <Axes: >

# %%
students["Marks"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales = {"Day": ["Mon", "Tue", "Wed", "Thu", "Fri"],
"Revenue": [1200,1500,900,2000,1800]}
s = pd.DataFrame(sales)
print(s["Revenue"].sum())
print(s["Revenue"].mean())
print(s[s["Revenue"] == s["Revenue"].max()])
print(s[s["Revenue"]>s["Revenue"].mean()])
s.plot(x="Day", y="Revenue", kind="bar")
# Out:
# 7400
# 1480.0
#    Day  Revenue
# 3  Thu     2000
#    Day  Revenue
# 1  Tue     1500
# 3  Thu     2000
# 4  Fri     1800
# <Axes: xlabel='Day'>
